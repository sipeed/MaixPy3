# %%
import os
print(os.uname())
# Out:
# [display] tips: os.environ(export) not _MAIX_WIDTH_ or _MAIX_HEIGHT_.
# posix.uname_result(sysname='Linux', nodename='juwan-N85-N870HL', release='5.8.0-41-generic', version='#46~20.04.1-Ubuntu SMP Mon Jan 18 17:52:23 UTC 2021', machine='x86_64')

# %%
from maix import display, camera

while True:
    tmp = camera.capture()
    if tmp:
        display.show(tmp)
# Out:
# Traceback (most recent call last):
#   File "<string>", line unknown, in <module>
# Remote.KeyboardInterrupt
